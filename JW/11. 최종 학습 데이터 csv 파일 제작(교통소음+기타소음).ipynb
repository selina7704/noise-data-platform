# %% [markdown]
# # I. 데이터 프레임 변환

# %%
#import os
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # warning 메시지 숨기기

import tensorflow as tf
print("Is GPU available:", tf.test.is_gpu_available())

import tensorflow as tf
print('tf.__version__:',tf.__version__)
# Out:
# 2025-03-06 01:16:03.117957: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-06 01:16:03.167519: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-06 01:16:03.969098: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /tmp/ipykernel_3866/181595091.py:5: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Is GPU available: True
# tf.__version__: 2.13.0
# 2025-03-06 01:16:05.105251: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-06 01:16:05.116412: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-06 01:16:05.119082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-06 01:16:05.898395: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-06 01:16:05.900187: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-06 01:16:05.901683: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-06 01:16:05.903134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 13576 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5

# %%
tf.config.set_visible_devices([], 'GPU')
# Out:
# 2025-03-06 01:16:06.079478: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-06 01:16:06.081069: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-06 01:16:06.082555: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## 1. 교통소음 데이터 프레임 생성

# %%
import pymysql
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
import config 
from config import DB_CONFIG
import pymysql  
 
# MySQL 연결
conn = pymysql.connect(
     host=DB_CONFIG['host'],
     user=DB_CONFIG['user'],
     password=DB_CONFIG['password'],
     database=DB_CONFIG['database'],
     port=DB_CONFIG['port']
 )
 
car_siren = f"SELECT * FROM merge50_car_siren"
car_horn = f"SELECT * FROM merge50_car_horn"
car_driving = f'SELECT * FROM merge50_car_driving'
motorcycle_horn  = f'SELECT * FROM merge50_motorcycle_horn'
motorcycle_driving  = f'SELECT * FROM merge50_motorcycle_driving'
 
car_siren_df =  pd.read_sql(car_siren, conn)
car_horn_df = pd.read_sql(car_horn, conn) 
car_driving_df = pd.read_sql(car_driving, conn) 
motorcycle_horn_df= pd.read_sql(motorcycle_horn, conn) 
motorcycle_driving_df = pd.read_sql(motorcycle_driving, conn) 
 
conn.close()
# Out:
# /tmp/ipykernel_3866/30002709.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   car_siren_df =  pd.read_sql(car_siren, conn)
# /tmp/ipykernel_3866/30002709.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   car_horn_df = pd.read_sql(car_horn, conn)
# /tmp/ipykernel_3866/30002709.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   car_driving_df = pd.read_sql(car_driving, conn)
# /tmp/ipykernel_3866/30002709.py:23: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   motorcycle_horn_df= pd.read_sql(motorcycle_horn, conn)
# /tmp/ipykernel_3866/30002709.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   motorcycle_driving_df = pd.read_sql(motorcycle_driving, conn)

# %%
print(f'car_siren 데이터 개수: {car_siren_df.shape[0]}')
print(f'car_horn 데이터 개수: {car_horn_df.shape[0]}')
print(f'car_driving 데이터 개수: {car_driving_df.shape[0]}')
print(f'motorcycle_horn 데이터 개수: {motorcycle_horn_df.shape[0]}')
print(f'motorcycle_driving 데이터 개수: {motorcycle_driving_df.shape[0]}')
# Out:
# car_siren 데이터 개수: 1990
# car_horn 데이터 개수: 3189
# car_driving 데이터 개수: 1682
# motorcycle_horn 데이터 개수: 4560
# motorcycle_driving 데이터 개수: 4735

# %%
#데이터프레임 병합 
df_combined = pd.concat([car_horn_df, car_siren_df,car_driving_df,motorcycle_horn_df,motorcycle_driving_df], ignore_index=True)

print(f'df_combined 행 개수: {len(df_combined)}') 
df_combined.head()
# Out:
# df_combined 행 개수: 16156
#                  fileName               labelName  area_start  area_end  \
# 0  1.car_horn_87900_1.wav  1.car_horn_87900_1.wav         2.0    58.719
# 1  1.car_horn_87964_1.wav  1.car_horn_87964_1.wav         2.0    59.747
# 2  1.car_horn_87987_1.wav  1.car_horn_87987_1.wav         2.0    59.217
# 3  1.car_horn_88000_1.wav  1.car_horn_88000_1.wav         2.0    57.389
# 4  1.car_horn_88001_1.wav  1.car_horn_88001_1.wav         2.0    58.207
#
#   category_01 category_02 category_03  decibel soundQuality subCategory  ...  \
# 0        교통소음         자동차        차량경적      116           정상       소형차경적  ...
# 1        교통소음         자동차        차량경적      102           정상       소형차경적  ...
# 2        교통소음         자동차        차량경적      112           정상       소형차경적  ...
# 3        교통소음         자동차        차량경적      112           정상       소형차경적  ...
# 4        교통소음         자동차        차량경적      122           정상       소형차경적  ...
#
#     mfcc_41   mfcc_42   mfcc_43    mfcc_44    mfcc_45    mfcc_46    mfcc_47  \
# 0 -1.194056 -0.757743 -2.858810  -5.101422  -0.198150   7.001447   6.203896
# 1 -7.923782  8.347244 -2.440833 -17.408949  -5.891588  22.778133  21.374588
# 2 -5.953082  1.538178 -0.032047 -10.759938 -10.296665  14.938017  19.099138
# 3 -5.018665  2.996135 -0.142866  -8.995171  -4.227169   8.116351  11.163322
# 4 -5.330876  2.107300  1.768516 -10.489394  -4.815802   9.592706  12.866017
#
#      mfcc_48    mfcc_49   mfcc_50
# 0  -2.862313 -10.336964 -8.593492
# 1 -19.310514 -26.457247  4.794274
# 2  -5.256958 -27.792421 -7.377015
# 3  -4.992955 -16.359087 -5.441961
# 4  -3.469832 -20.286922 -6.563427
#
# [5 rows x 82 columns]

# %% [markdown]
# ## 2. 기타소음 데이터 프레임 생성

# %%
import os
import json
import pandas as pd

def load_and_flatten_json(root_dir):
    data = []
    for subdir, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.json'):
                filepath = os.path.join(subdir, file)
                with open(filepath, 'r', encoding='utf-8') as f:
                    try:
                        json_data = json.load(f)
                        info = json_data.get('info', {})
                        license_info = json_data.get('license', {})
                        audio = json_data.get('audio', {})
                        environment = json_data.get('environment', {})
                        annotations = json_data.get('annotations', [])

                        area_start = None
                        area_end = None
                        category_01 = None
                        category_02 = None
                        category_03 = None
                        labelName = None
                        soundQuality = None
                        decibel = None
                        subCategory = None

                        if annotations and isinstance(annotations, list) and len(annotations) > 0:
                            annotation = annotations[0]
                            if isinstance(annotation, dict):
                                area = annotation.get('area', {})
                                area_start = area.get('start')
                                area_end = area.get('end')
                                categories = annotation.get('categories', {})
                                category_01 = categories.get('category_01')
                                category_02 = categories.get('category_02')
                                category_03 = categories.get('category_03')
                                labelName = annotation.get('labelName')
                                soundQuality = annotation.get('soundQuality')
                                decibel = annotation.get('decibel')
                                subCategory = annotation.get('subCategory')

                        row = {
                            'area_start': area_start,
                            'area_end': area_end,
                            'category_01': category_01,
                            'category_02': category_02,
                            'category_03': category_03,
                            'decibel': decibel,
                            'labelName': labelName,
                            'soundQuality': soundQuality,
                            'subCategory': subCategory,
                            'bitRate': audio.get('bitRate'),
                            'duration': audio.get('duration'),
                            'fileFormat': audio.get('fileFormat'),
                            'fileName': audio.get('fileName'),
                            'fileSize': audio.get('fileSize'),
                            'recodingType': audio.get('recodingType'),
                            'sampleRate': audio.get('sampleRate'),
                            'acqDevice': environment.get('acqDevice'),
                            'acqMethod': environment.get('acqMethod'),
                            'acqType': environment.get('acqType'),
                            'areaUse': environment.get('areaUse'),
                            'dayNight': environment.get('dayNight'),
                            'direction': environment.get('direction'),
                            'distance': environment.get('distance'),
                            'district': environment.get('district'),
                            'latitude': environment.get('gps', {}).get('latitude'),
                            'longitude': environment.get('gps', {}).get('longitude'),
                            'micClass': environment.get('micClass'),
                            'obstacle': environment.get('obstacle'),
                            'place': environment.get('place'),
                            'recordingTime': environment.get('recordingTime'),
                            'urban': environment.get('urban'),
                            'weather': environment.get('weather'),
                            'contributor': info.get('contributor'),
                            'dateCreated': info.get('dateCreated'),
                            'description': info.get('description'),
                            'uri': info.get('uri'),
                            'version': info.get('version'),
                            'year': info.get('year'),
                            'license_name': license_info.get('name'),
                            'license_url': license_info.get('url'),
                        }
                        data.append(row)
                    except json.JSONDecodeError as e:
                        print(f"Error decoding JSON file: {filepath} - {e}")
    return pd.DataFrame(data)

# JSON 파일 로드 및 평탄화
root_dir_2 = '/home/ubuntu/data/etc_noise_data_training'
etc_json_df = load_and_flatten_json(root_dir_2)

print("\n기타 소음 JSON 데이터프레임:")
print(etc_json_df.head())
print(etc_json_df.info())
# Out:
# 기타 소음 JSON 데이터프레임:
#    area_start  area_end category_01 category_02 category_03  decibel  \
# 0        1.95     6.290        생활소음          동물           개      104
# 1        2.00    47.060        생활소음          동물           개       61
# 2        2.00    43.526        생활소음          동물           개       46
# 3        2.00    14.286        생활소음          동물           개       52
# 4        2.00    13.025        생활소음          동물           개      110
#
#           labelName soundQuality subCategory   bitRate  ...  urban weather  \
# 0  7.동물_93792_1.wav           정상           개  1411kbps  ...    수원시      맑음
# 1  7.동물_50333_1.wav           정상           개  1411kbps  ...    수원시      맑음
# 2  7.동물_50130_1.wav           정상           개  1411kbps  ...    수원시      맑음
# 3  7.동물_93920_1.wav           정상           개  1411kbps  ...    수원시      맑음
# 4  7.동물_49688_1.wav           정상           개  1411kbps  ...    수원시      맑음
#
#   contributor  dateCreated description                      uri version  year  \
# 0         IMR   2021-12-08   도시 소리 데이터  https://www.aihub.or.kr     1.0  2021
# 1         IMR   2021-11-08   도시 소리 데이터  https://www.aihub.or.kr     1.0  2021
# 2         IMR   2021-11-08   도시 소리 데이터  https://www.aihub.or.kr     1.0  2021
# 3         IMR   2021-12-08   도시 소리 데이터  https://www.aihub.or.kr     1.0  2021
# 4         IMR   2021-11-08   도시 소리 데이터  https://www.aihub.or.kr     1.0  2021
#
#   license_name              license_url
# 0         CC 0  https://www.aihub.or.kr
# 1         CC 0  https://www.aihub.or.kr
# 2         CC 0  https://www.aihub.or.kr
# 3         CC 0  https://www.aihub.or.kr
# 4         CC 0  https://www.aihub.or.kr
#
# [5 rows x 40 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14239 entries, 0 to 14238
# Data columns (total 40 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_start     14239 non-null  float64
#  1   area_end       14239 non-null  float64
#  2   category_01    14239 non-null  object
#  3   category_02    14239 non-null  object
#  4   category_03    14239 non-null  object
#  5   decibel        14239 non-null  int64
#  6   labelName      14239 non-null  object
#  7   soundQuality   14239 non-null  object
#  8   subCategory    14239 non-null  object
#  9   bitRate        14239 non-null  object
#  10  duration       14239 non-null  float64
#  11  fileFormat     14239 non-null  object
#  12  fileName       14239 non-null  object
#  13  fileSize       14239 non-null  int64
#  14  recodingType   14239 non-null  object
#  15  sampleRate     14239 non-null  object
#  16  acqDevice      14239 non-null  object
#  17  acqMethod      14239 non-null  object
#  18  acqType        14239 non-null  object
#  19  areaUse        14239 non-null  object
#  20  dayNight       14239 non-null  object
#  21  direction      14239 non-null  object
#  22  distance       14239 non-null  object
#  23  district       14239 non-null  object
#  24  latitude       14239 non-null  float64
#  25  longitude      14239 non-null  float64
#  26  micClass       14239 non-null  object
#  27  obstacle       14239 non-null  object
#  28  place          14239 non-null  object
#  29  recordingTime  14239 non-null  object
#  30  urban          14239 non-null  object
#  31  weather        14239 non-null  object
#  32  contributor    14239 non-null  object
#  33  dateCreated    14239 non-null  object
#  34  description    14239 non-null  object
#  35  uri            14239 non-null  object
#  36  version        14239 non-null  float64
#  37  year           14239 non-null  int64
#  38  license_name   14239 non-null  object
#  39  license_url    14239 non-null  object
# dtypes: float64(6), int64(3), object(31)
# memory usage: 4.3+ MB
# None

# %%
import librosa
import numpy as np
import os
import pandas as pd
import re
import json

# 한글-영어 매칭 딕셔너리 보완
kor_eng_dict = {
    "자동차": "car",
    "이륜자동차": "motorcycle",
    "경적": "horn",
    "사이렌": "siren",
    "주행음": "driving_sound",
    # 필요한 모든 매핑 추가
}

# 파일명 정규화 함수 수정
def normalize_filename(filename):
    # 확장자 제거
    name, ext = os.path.splitext(filename)

    # 대소문자 변환 및 공백 제거
    name = name.lower().replace(' ', '')

    # 한글-영어 변환 적용
    for kor, eng in kor_eng_dict.items():
        name = name.replace(kor, eng)

    # 정규식으로 고유 ID 추출
    match = re.match(r".*?_(\d+)(?:_\d+)?$", name)
    if match:
        file_id = match.group(1)
    else:
        file_id = None

    return name, ext, file_id

# 매칭 검사 함수 수정
def find_mismatched_files(directory):
    wav_files = {}
    json_files = {}

    # 모든 폴더 순회하며 파일 수집
    for root, _, files in os.walk(directory):
        for file in files:
            name, ext, file_id = normalize_filename(file)
            if file_id is None:
                continue  # ID가 없는 파일은 패스
            file_path = os.path.join(root, file)
            if ext == ".wav":
                wav_files[file_id] = file_path
            elif ext == ".json":
                json_files[file_id] = file_path

    # 매칭되지 않은 파일 찾기
    mismatched_wav = set(wav_files.keys()) - set(json_files.keys())
    mismatched_json = set(json_files.keys()) - set(wav_files.keys())

    return mismatched_wav, mismatched_json, wav_files, json_files

def extract_mfcc(wav_path):
    """
    주어진 WAV 파일 경로에서 MFCC 특징을 추출합니다.
    """
    try:
        audio, sr = librosa.load(wav_path, sr=None)
        mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=50)
        mfcc_mean = np.mean(mfcc, axis=1).tolist()
        return mfcc_mean
    except Exception as e:
        print(f"Error processing WAV file: {wav_path} - {e}")
        return None

def load_wav_and_extract_mfcc(root_dir, df_json):
    """
    주어진 디렉토리의 모든 WAV 파일을 로드하고 MFCC 특징을 추출하여 DataFrame에 추가합니다.
    """
    mfcc_data = []
    for index, row in df_json.iterrows():
        wav_filename = row['fileName']
        wav_path = None

        # JSON 파일 이름 정규화
        json_name, _, json_id = normalize_filename(wav_filename)

        # 모든 하위 디렉토리에서 WAV 파일 검색
        for subdir, dirs, files in os.walk(root_dir):
            for file in files:
                wav_name, _, wav_id = normalize_filename(file)
                if json_id == wav_id and file.endswith('_1.wav'):  # ID가 일치하고 _1로 끝나는 파일
                    wav_path = os.path.join(subdir, file)
                    break

        if wav_path:
            mfcc_features = extract_mfcc(wav_path)
            mfcc_data.append(mfcc_features)
        else:
            print(f"WAV file not found for: {wav_filename}, looking for ID: {json_id}")
            mfcc_data.append(None)

    mfcc_columns = [f'mfcc_{i+1}' for i in range(50)]
    df_mfcc = pd.DataFrame(mfcc_data, columns=mfcc_columns)
    return pd.concat([df_json, df_mfcc], axis=1)

# JSON 파일 로드 및 평탄화
root_dir_2 = '/home/ubuntu/data/etc_noise_data_training'
etc_json_df = load_and_flatten_json(root_dir_2)

# WAV 파일 로드 및 MFCC 추출
df_final_2 = load_wav_and_extract_mfcc(root_dir_2, etc_json_df)
print(df_final_2.head())
# Out:
#    area_start  area_end category_01 category_02 category_03  decibel  \
# 0        1.95     6.290        생활소음          동물           개      104
# 1        2.00    47.060        생활소음          동물           개       61
# 2        2.00    43.526        생활소음          동물           개       46
# 3        2.00    14.286        생활소음          동물           개       52
# 4        2.00    13.025        생활소음          동물           개      110
#
#           labelName soundQuality subCategory   bitRate  ...   mfcc_41  \
# 0  7.동물_93792_1.wav           정상           개  1411kbps  ... -0.254269
# 1  7.동물_50333_1.wav           정상           개  1411kbps  ...  1.303359
# 2  7.동물_50130_1.wav           정상           개  1411kbps  ... -1.888240
# 3  7.동물_93920_1.wav           정상           개  1411kbps  ... -0.427137
# 4  7.동물_49688_1.wav           정상           개  1411kbps  ... -1.351582
#
#     mfcc_42   mfcc_43   mfcc_44   mfcc_45   mfcc_46   mfcc_47   mfcc_48  \
# 0 -0.674908 -0.405706  0.082630 -1.324903 -0.683356 -0.175445  0.108566
# 1  0.250763 -1.871798 -1.235186  0.887074  0.043997 -0.773939  1.841453
# 2 -1.821449 -1.663048 -0.816676 -0.185362  0.576819  1.497391  1.939414
# 3  1.955062  2.212069  1.263791  2.206821  0.963472 -0.111466 -0.275661
# 4 -2.387926 -0.844139 -1.847453 -1.289088 -1.710687 -2.376323 -0.797052
#
#     mfcc_49   mfcc_50
# 0 -0.436502 -1.236410
# 1  1.114058 -1.070323
# 2  0.857066  0.462267
# 3 -0.333139 -0.461667
# 4 -1.352284 -0.342182
#
# [5 rows x 90 columns]

# %% [markdown]
# ## 3. 최종 데이터프레임 생성

# %%
# df_combined의 열 목록 가져오기
combined_cols = df_combined.columns.tolist()

# df_final_2에서 df_combined에 있는 열만 선택
final_cols = [col for col in combined_cols if col in df_final_2.columns]
df_final_2 = df_final_2[final_cols]

# df_final_2의 열 순서를 df_combined의 열 순서에 맞춰 변경
df_final_2 = df_final_2[combined_cols[:len(final_cols)]]

# 두 데이터 프레임 합치기
df_result = pd.concat([df_combined, df_final_2], axis=0)

print(df_result)
# Out:
#                      fileName               labelName  area_start  area_end  \
# 0      1.car_horn_87900_1.wav  1.car_horn_87900_1.wav        2.00    58.719
# 1      1.car_horn_87964_1.wav  1.car_horn_87964_1.wav        2.00    59.747
# 2      1.car_horn_87987_1.wav  1.car_horn_87987_1.wav        2.00    59.217
# 3      1.car_horn_88000_1.wav  1.car_horn_88000_1.wav        2.00    57.389
# 4      1.car_horn_88001_1.wav  1.car_horn_88001_1.wav        2.00    58.207
# ...                       ...                     ...         ...       ...
# 14234          8.도구_78707.wav        8.도구_78707_1.wav        0.44    58.360
# 14235          8.도구_78954.wav        8.도구_78954_1.wav        0.15    57.420
# 14236          8.도구_18554.wav        8.도구_18554_1.wav        2.00     8.674
# 14237          8.도구_66824.wav        8.도구_66824_1.wav        0.20    49.030
# 14238          8.도구_33264.wav        8.도구_33264_1.wav        2.00     7.474
#
#       category_01 category_02 category_03  decibel soundQuality subCategory  \
# 0            교통소음         자동차        차량경적      116           정상       소형차경적
# 1            교통소음         자동차        차량경적      102           정상       소형차경적
# 2            교통소음         자동차        차량경적      112           정상       소형차경적
# 3            교통소음         자동차        차량경적      112           정상       소형차경적
# 4            교통소음         자동차        차량경적      122           정상       소형차경적
# ...           ...         ...         ...      ...          ...         ...
# 14234        생활소음          도구          공구      116           정상          망치
# 14235        생활소음          도구          공구      104           정상          망치
# 14236        생활소음          도구          공구       46           정상          망치
# 14237        생활소음          도구          공구      105           정상          망치
# 14238        생활소음          도구          공구       97           정상          망치
#
#        ...   mfcc_41   mfcc_42   mfcc_43    mfcc_44    mfcc_45    mfcc_46  \
# 0      ... -1.194056 -0.757743 -2.858810  -5.101422  -0.198150   7.001447
# 1      ... -7.923782  8.347244 -2.440833 -17.408949  -5.891588  22.778133
# 2      ... -5.953082  1.538178 -0.032047 -10.759938 -10.296665  14.938017
# 3      ... -5.018665  2.996135 -0.142866  -8.995171  -4.227169   8.116351
# 4      ... -5.330876  2.107300  1.768516 -10.489394  -4.815802   9.592706
# ...    ...       ...       ...       ...        ...        ...        ...
# 14234  ...  1.111959  1.236529  1.614501   0.086138   0.028951  -0.253908
# 14235  ... -1.231155 -1.392887 -1.813820  -0.471907   0.548512  -0.216399
# 14236  ...  1.756460 -2.475883  0.887913   0.071810  -0.944529   1.765205
# 14237  ... -2.568715 -1.328159 -0.409700   0.190598   0.440036   0.208449
# 14238  ...  0.643109  0.122164 -0.586995   0.007654   0.676601   1.536853
#
#          mfcc_47    mfcc_48    mfcc_49   mfcc_50
# 0       6.203896  -2.862313 -10.336964 -8.593492
# 1      21.374588 -19.310514 -26.457247  4.794274
# 2      19.099138  -5.256958 -27.792421 -7.377015
# 3      11.163322  -4.992955 -16.359087 -5.441961
# 4      12.866017  -3.469832 -20.286922 -6.563427
# ...          ...        ...        ...       ...
# 14234  -1.313876  -1.611521  -2.307126 -1.273106
# 14235  -1.415591   0.020816   1.320833  0.656980
# 14236  -0.601994   1.356133   0.950066 -1.457089
# 14237  -1.235412   0.086889   0.169911 -1.426607
# 14238   2.281101   0.112200  -0.210119  1.397945
#
# [30395 rows x 82 columns]

# %%
# 각 열의 null 값 개수 확인
print(df_result.isnull().sum())

# 데이터프레임 전체에 null 값 있는지 확인
print(df_result.isnull().values.any())
# Out:
# fileName       0
# labelName      0
# area_start     0
# area_end       0
# category_01    0
#               ..
# mfcc_46        0
# mfcc_47        0
# mfcc_48        0
# mfcc_49        0
# mfcc_50        0
# Length: 82, dtype: int64
# False

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30395 entries, 0 to 14238
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fileName       30395 non-null  object
#  1   labelName      30395 non-null  object
#  2   area_start     30395 non-null  float64
#  3   area_end       30395 non-null  float64
#  4   category_01    30395 non-null  object
#  5   category_02    30395 non-null  object
#  6   category_03    30395 non-null  object
#  7   decibel        30395 non-null  int64
#  8   soundQuality   30395 non-null  object
#  9   subCategory    30395 non-null  object
#  10  bitRate        30395 non-null  object
#  11  duration       30395 non-null  float64
#  12  fileFormat     30395 non-null  object
#  13  fileSize       30395 non-null  int64
#  14  recodingType   30395 non-null  object
#  15  sampleRate     30395 non-null  object
#  16  acqDevice      30395 non-null  object
#  17  acqMethod      30395 non-null  object
#  18  acqType        30395 non-null  object
#  19  areaUse        30395 non-null  object
#  20  dayNight       30395 non-null  object
#  21  direction      30395 non-null  object
#  22  distance       30395 non-null  object
#  23  district       30395 non-null  object
#  24  latitude       30395 non-null  float64
#  25  longitude      30395 non-null  float64
#  26  micClass       30395 non-null  object
#  27  obstacle       30395 non-null  object
#  28  place          30395 non-null  object
#  29  recordingTime  30395 non-null  object
#  30  urban          30395 non-null  object
#  31  weather        30395 non-null  object
#  32  mfcc_1         30395 non-null  float64
#  33  mfcc_2         30395 non-null  float64
#  34  mfcc_3         30395 non-null  float64
#  35  mfcc_4         30395 non-null  float64
#  36  mfcc_5         30395 non-null  float64
#  37  mfcc_6         30395 non-null  float64
#  38  mfcc_7         30395 non-null  float64
#  39  mfcc_8         30395 non-null  float64
#  40  mfcc_9         30395 non-null  float64
#  41  mfcc_10        30395 non-null  float64
#  42  mfcc_11        30395 non-null  float64
#  43  mfcc_12        30395 non-null  float64
#  44  mfcc_13        30395 non-null  float64
#  45  mfcc_14        30395 non-null  float64
#  46  mfcc_15        30395 non-null  float64
#  47  mfcc_16        30395 non-null  float64
#  48  mfcc_17        30395 non-null  float64
#  49  mfcc_18        30395 non-null  float64
#  50  mfcc_19        30395 non-null  float64
#  51  mfcc_20        30395 non-null  float64
#  52  mfcc_21        30395 non-null  float64
#  53  mfcc_22        30395 non-null  float64
#  54  mfcc_23        30395 non-null  float64
#  55  mfcc_24        30395 non-null  float64
#  56  mfcc_25        30395 non-null  float64
#  57  mfcc_26        30395 non-null  float64
#  58  mfcc_27        30395 non-null  float64
#  59  mfcc_28        30395 non-null  float64
#  60  mfcc_29        30395 non-null  float64
#  61  mfcc_30        30395 non-null  float64
#  62  mfcc_31        30395 non-null  float64
#  63  mfcc_32        30395 non-null  float64
#  64  mfcc_33        30395 non-null  float64
#  65  mfcc_34        30395 non-null  float64
#  66  mfcc_35        30395 non-null  float64
#  67  mfcc_36        30395 non-null  float64
#  68  mfcc_37        30395 non-null  float64
#  69  mfcc_38        30395 non-null  float64
#  70  mfcc_39        30395 non-null  float64
#  71  mfcc_40        30395 non-null  float64
#  72  mfcc_41        30395 non-null  float64
#  73  mfcc_42        30395 non-null  float64
#  74  mfcc_43        30395 non-null  float64
#  75  mfcc_44        30395 non-null  float64
#  76  mfcc_45        30395 non-null  float64
#  77  mfcc_46        30395 non-null  float64
#  78  mfcc_47        30395 non-null  float64
#  79  mfcc_48        30395 non-null  float64
#  80  mfcc_49        30395 non-null  float64
#  81  mfcc_50        30395 non-null  float64
# dtypes: float64(55), int64(2), object(25)
# memory usage: 19.2+ MB

# %%
print(df_result['category_03'].value_counts())
# Out:
# category_03
# 이륜차주행음    4735
# 이륜차경적     4560
# 차량경적      3189
# 항타기       3036
# 콘크리트펌프    2730
# 공구        2216
# 발전기       2164
# 개         2077
# 고양이       2016
# 차량사이렌     1990
# 차량주행음     1682
# Name: count, dtype: int64

# %% [markdown]
# ## 4. 기타소음 분류 컬럼 추가

# %%
# df_result에서 실제 라벨을 기준으로 정상 데이터와 기타 소음 라벨링
valid_labels = ['차량경적', '차량주행음', '이륜차경적', '이륜차주행음', '차량사이렌']  # 정상 라벨

# 'category_03' 컬럼이 정상 라벨이면 그대로 두고, 그렇지 않으면 '기타소음'으로 설정
df_result['ood_label'] = df_result['category_03'].apply(lambda x: x if x in valid_labels else '기타소음')

# %%
print(df_result['category_03'].value_counts())
# Out:
# category_03
# 이륜차주행음    4735
# 이륜차경적     4560
# 차량경적      3189
# 항타기       3036
# 콘크리트펌프    2730
# 공구        2216
# 발전기       2164
# 개         2077
# 고양이       2016
# 차량사이렌     1990
# 차량주행음     1682
# Name: count, dtype: int64

# %%
print(df_result['ood_label'].value_counts())
# Out:
# ood_label
# 기타소음      14239
# 이륜차주행음     4735
# 이륜차경적      4560
# 차량경적       3189
# 차량사이렌      1990
# 차량주행음      1682
# Name: count, dtype: int64

# %% [markdown]
# ## 5. csv 파일로 저장

# %%
import pandas as pd

# 현재 데이터프레임 원본을 CSV 파일로 저장
df_result.to_csv('final_training_data_original.csv', index=False)

# %%
import pandas as pd

# category_03의 각 레이블별로 1500개씩 랜덤 샘플링
sampled_data_category = df_result.groupby('category_03').apply(lambda x: x.sample(min(len(x), 1500), random_state=42))

# 샘플링된 데이터를 CSV 파일로 저장
sampled_data_category.to_csv('final_training_data_sampled_1500_category_03.csv', index=False)

# %%
print(sampled_data_category['category_03'].value_counts())
# Out:
# category_03
# 개         1500
# 고양이       1500
# 공구        1500
# 발전기       1500
# 이륜차경적     1500
# 이륜차주행음    1500
# 차량경적      1500
# 차량사이렌     1500
# 차량주행음     1500
# 콘크리트펌프    1500
# 항타기       1500
# Name: count, dtype: int64

# %%
print(sampled_data_category['ood_label'].value_counts())
# Out:
# ood_label
# 기타소음      9000
# 이륜차경적     1500
# 이륜차주행음    1500
# 차량경적      1500
# 차량사이렌     1500
# 차량주행음     1500
# Name: count, dtype: int64

# %%
import pandas as pd

def sample_ood_with_category_balance(df, n=1500, random_state=42):
    """ood_label을 기준으로 샘플링하고, '기타소음'의 경우 category_03 분포를 균등하게 조정합니다."""

    sampled_data = []
    for ood_label, group in df.groupby('ood_label'):
        if ood_label == '기타소음':
            # '기타소음'의 경우 category_03 분포를 균등하게 조정하여 총 1500개 샘플링
            category_counts = group['category_03'].value_counts()
            num_categories = len(category_counts)
            samples_per_category = n // num_categories  # 각 카테고리별 샘플 수
            remainder = n % num_categories  # 나머지 샘플 수

            samples = []
            for category, count in category_counts.items():
                sample_count = min(count, samples_per_category)
                samples.append(group[group['category_03'] == category].sample(sample_count, random_state=random_state))

            # 나머지 샘플을 랜덤하게 추가
            remaining_samples = pd.concat(samples)
            if remainder > 0:
                remaining_samples = pd.concat([remaining_samples, group[~group.index.isin(remaining_samples.index)].sample(remainder, random_state=random_state)])

            sampled_data.append(remaining_samples)
        else:
            # 다른 ood_label은 기존 방식대로 샘플링
            sampled_data.append(group.sample(min(len(group), n), random_state=random_state))

    return pd.concat(sampled_data)

# 수정된 함수를 사용하여 샘플링
sampled_data_ood = sample_ood_with_category_balance(df_result)

# 샘플링된 데이터를 CSV 파일로 저장
sampled_data_ood.to_csv('final_training_data_sampled_1500_ood_label.csv', index=False)

# %%
print(sampled_data_ood['category_03'].value_counts())
# Out:
# category_03
# 이륜차경적     1500
# 이륜차주행음    1500
# 차량경적      1500
# 차량사이렌     1500
# 차량주행음     1500
# 항타기        250
# 콘크리트펌프     250
# 공구         250
# 발전기        250
# 개          250
# 고양이        250
# Name: count, dtype: int64

# %%
print(sampled_data_ood['ood_label'].value_counts())
# Out:
# ood_label
# 기타소음      1500
# 이륜차경적     1500
# 이륜차주행음    1500
# 차량경적      1500
# 차량사이렌     1500
# 차량주행음     1500
# Name: count, dtype: int64

# %% [markdown]
# # [참고] 디버깅

# %% [markdown]
# > 문제 상황
# - /home/ubuntu/data/etc_noise_data_training/WAV/TS_3.사업장소음 하위 wav 파일이 jupyter로 로드되지 않음
#
# > 문제 발생 경위
# 1. 데이터 업로드 담당자가 해당 디렉토리의 용량이 많은 관계로 해당 디렉토리만 7zip 파일 확장자로 ubuntu에 업로드 함.
# 2. 터미널에서 7z 명령어 설치 후 일괄 압축해제 함(sudo apt-get install p7zip-full)
# 3. 해당 디렉토리들의 권한이 drwx------로 설정되어 있어, ubuntu 외 사용자가 접근할 수 없게 됨. (zip 파일은 자동으로drwxr-xr-x로 설정됨)
#
# > 문제 해결
# - chmod 명령어를 통해 권한 변경 (sudo chmod 755 /home/ubuntu/data/etc_noise_data_training/WAV/TS_3.사업장소음/*)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# 파일 경로
file_path = "/home/ubuntu/data/etc_noise_data_training/WAV/TS_3.사업장소음/21.발전기/9.공사장_8924_1.wav"

# librosa를 사용하여 오디오 파일 로드
y, sr = librosa.load(file_path)

# 오디오 데이터 확인
print(f"샘플링 레이트 (Sampling Rate): {sr} Hz")
print(f"오디오 데이터 길이: {len(y)} samples")
print(f"오디오 데이터: {y}")

# 파형 그래프 출력
plt.figure(figsize=(14, 5))
librosa.display.waveshow(y, sr=sr)
plt.title("Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# 스펙트로그램 출력
D = librosa.amplitude_to_db(abs(librosa.stft(y)), ref=np.max)
plt.figure(figsize=(14, 5))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram")
plt.show()
# Out:
# /home/lab06/.local/lib/python3.8/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/librosa/core/audio.py:164, in load(path, sr, mono, offset, duration, dtype, res_type)
#     163 try:
# --> 164     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     166 except RuntimeError as exc:
#     167     # If soundfile failed, try audioread instead
#
# File ~/.local/lib/python3.8/site-packages/librosa/core/audio.py:195, in __soundfile_load(path, offset, duration, dtype)
#     193 else:
#     194     # Otherwise, create the soundfile object
# --> 195     context = sf.SoundFile(path)
#     197 with context as sf_desc:
#
# File /home/ubuntu/anaconda3/envs/ml_env/lib/python3.8/site-packages/soundfile.py:690, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     688 self._info = _create_info_struct(file, mode, samplerate, channels,
#     689                                  format, subtype, endian)
# --> 690 self._file = self._open(file, mode_int, closefd)
#     691 if set(mode).issuperset('r+') and self.seekable():
#     692     # Move write position to 0 (like in Python file objects)
#
# File /home/ubuntu/anaconda3/envs/ml_env/lib/python3.8/site-packages/soundfile.py:1265, in SoundFile._open(self, file, mode_int, closefd)
#    1264     err = _snd.sf_error(file_ptr)
# -> 1265     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1266 if mode_int == _snd.SFM_WRITE:
#    1267     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1268     # when opening a named pipe in SFM_WRITE mode.
#    1269     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening '/home/ubuntu/data/etc_noise_data_training/WAV/TS_3.사업장소음/21.발전기/9.공사장_8924_1.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[9], line 9
#       6 file_path = "/home/ubuntu/data/etc_noise_data_training/WAV/TS_3.사업장소음/21.발전기/9.공사장_8924_1.wav"
#       8 # librosa를 사용하여 오디오 파일 로드
# ----> 9 y, sr = librosa.load(file_path)
#      11 # 오디오 데이터 확인
#      12 print(f"샘플링 레이트 (Sampling Rate): {sr} Hz")
#
# File ~/.local/lib/python3.8/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~/.local/lib/python3.8/site-packages/librosa/core/audio.py:170, in load(path, sr, mono, offset, duration, dtype, res_type)
#     168 if isinstance(path, (str, pathlib.PurePath)):
#     169     warnings.warn("PySoundFile failed. Trying audioread instead.", stacklevel=2)
# --> 170     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     171 else:
#     172     raise exc
#
# File ~/.local/lib/python3.8/site-packages/librosa/core/audio.py:226, in __audioread_load(path, offset, duration, dtype)
#     223     reader = path
#     224 else:
#     225     # If the input was not an audioread object, try to open it
# --> 226     reader = audioread.audio_open(path)
#     228 with reader as input_file:
#     229     sr_native = input_file.samplerate
#
# File /home/ubuntu/anaconda3/envs/ml_env/lib/python3.8/site-packages/audioread/__init__.py:127, in audio_open(path, backends)
#     125 for BackendClass in backends:
#     126     try:
# --> 127         return BackendClass(path)
#     128     except DecodeError:
#     129         pass
#
# File /home/ubuntu/anaconda3/envs/ml_env/lib/python3.8/site-packages/audioread/rawread.py:59, in RawAudioFile.__init__(self, filename)
#      58 def __init__(self, filename):
# ---> 59     self._fh = open(filename, 'rb')
#      61     try:
#      62         self._file = aifc.open(self._fh)
#
# PermissionError: [Errno 13] Permission denied: '/home/ubuntu/data/etc_noise_data_training/WAV/TS_3.사업장소음/21.발전기/9.공사장_8924_1.wav'

# %%
import json

file_path = "/home/ubuntu/data/etc_noise_data_training/JSON/공사장/발전기/9.공사장_8924.json"

with open(file_path, 'r') as f:
    data = json.load(f)

print(data)
# Out:
# {'info': {'description': '도시 소리 데이터', 'uri': 'https://www.aihub.or.kr', 'version': 1.0, 'year': 2021, 'contributor': 'IMR', 'dateCreated': '2021-09-04'}, 'license': {'url': 'https://www.aihub.or.kr', 'name': 'CC 0'}, 'audio': {'fileName': '9.공사장_8924.wav', 'fileSize': 6064408, 'duration': 34.378, 'fileFormat': 'wav', 'sampleRate': '44.1kHz', 'bitRate': '1411kbps', 'recodingType': 'Stereo'}, 'environment': {'recordingTime': '14:30', 'dayNight': '주간', 'urban': '서울특별시', 'district': '돈암동', 'place': '도로변', 'areaUse': '주거지역', 'weather': '맑음', 'direction': '우', 'distance': '10m', 'obstacle': '없음', 'acqMethod': '자연적', 'acqType': '제작', 'acqDevice': '갤럭시탭S6', 'micClass': '무지향성', 'gps': {'latitude': 37.6, 'longitude': 127.01}}, 'annotations': [{'labelName': '9.공사장_8924_1.wav', 'area': {'start': 2, 'end': 32.378}, 'categories': {'category_01': '사업장소음', 'category_02': '공사장', 'category_03': '발전기'}, 'subCategory': '소형발전기', 'soundQuality': '정상', 'decibel': 122}]}

# %%
import librosa

file_path = "/home/ubuntu/data/etc_noise_data_training/WAV/TS_3.사업장소음/21.발전기/9.공사장_8924_1.wav"

y, sr = librosa.load(file_path)

print(y)
# Out:
# [-1.9712079e-06 -1.7236640e-06 -1.0081317e-06 ... -4.4537317e-02
#  -5.0755091e-02  0.0000000e+00]
